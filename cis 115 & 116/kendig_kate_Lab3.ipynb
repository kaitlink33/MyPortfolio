# %% [markdown]
# # Lab 2: Boolean Logic
# 1. Complete all of the prompts below. Some require writting Python code, while others require fixing existing code. 2. Once you have completed all parts. Save your lab and rename it as *lastName_firstName_lab2*.ipynb.
# 3. Submit your lab to canvas.
# 4. Raise your hand to request a TA/professor to check off your lab.
#     1. If any corrections are needed, you can resubmit your lab as many times as needed during the class period.
#
# **Be sure to make sure you are checked off and a grade appears in canvas for today _before_ you leave class.**

# %% [markdown]
# ## 1 Basic if
#
# Without changing the value of the variable __test__, write an if statement (no `else` clause) to print "The if statement condition is true." Your if statement cannot use any comparison operators.

# %%
test = True
if test:
    print("The if statement condition is true.")
# Out:
# The if statement condition is true.

# %% [markdown]
# ## 2 When all else fails, "else"
#
# Conditional statements can be expanded to include a __false__ branch by adding an `else` clause.  Without changing the value of the variable, write an if/else statement that prints "All other conditions in this statement are false." Your if statement cannot use any comparison operators.

# %%
test = False
if test:
    print("The if statement condition is true.")
else:
    print("All other conditions in this statement are false.")
# Out:
# All other conditions in this statement are false.

# %% [markdown]
# # 3 Branching
# Write a conditional statement that has one `if` clause, one `elif` clause, and one `else` clause for the following rules (*rules are not listed in any particular order*):
#
# - When x is greater than or less than y, print the result of dividing x by y.
# - When x is equal to y, print 'A number divided by iteself is always 1`.
# - When y is 0, print 'You cannot divide by 0'.

# %%
# modify the values of x and y to test your code!
x = 1
y = 2
if y==0:
    print("You cannot divide by zero.")
elif x==y:
    print("A number divided by itself is always 1.")
else:
    print(x/y)

# %% [markdown]
# # 4 Evaluation
# Employee evaluations are coming up and management needs a way to assign the final results.  Evaluation results are formulated from a score between 1 and 10 (1 being the best and 10 being the worst), along with how long the employee has been working at the company.  According to the following rules, create a single conditional statement (this may include one `if` clause, any number of `elif` clauses, and one `else` clause) that  follows the following rules:
# 1. For an employee that has a score of 1, print that a raise will be given!
# 2. For an employee with a score between 2 and 4 (inclusive), print that they should keep up the good work!
# 3. For an employee with a score of 5, print that they are doing fine, but should work harder.
# 4. For an employee with a score between 6 and 9 (inclusive), print that they will be put on warning.
# 5. If a new employee (employed for 3 or fewer years) gets a 10, then print they are fired.
# 6. Otherwise, print that the employee has one month to improve or else they are fired.
#
# You should change the value of the variables below to test your conditional statement.

# %%
# variable to store the evaluation score of the employee
result = 5
# number of years the employee has been working
years = 2
if result == 1:
    print("A raise will be given!")
elif result <= 4:
    print("They should keep up the good work.")
elif result == 5:
    print("They are doing fine, but should work harder.")
elif result <= 9:
    print("They will be put on warning.")
elif result == 10 and years <= 3:
    print("They are to be fired.") 
else: 
    print("The employee has one month to improve or they will be fired.")

# %% [markdown]
# ## 5 Grading Scale
# Fix the conditional below so that it properly prints out the correct grades for a 92/75/60/50 grading scale.

# %%
# modify score as needed to test
score = 60
if score >= 92:
    print("Your grade is an A.")
elif score < 92 and score >= 75:
    print("Your grade is a B.")
elif score >= 60 and score < 75:
    print("Your grade is a C.")
elif score >= 50 and score < 60:
    print("Your grade is a D.")
else:
    print("Your grade is a F.")
# Out:
# Your grade is a D.

# %% [markdown]
# ## 6 Anchovies Anyone?
# Given the truth table below, write a conditional statement that prints True when the output is True, and False when output is False.  This is much like the activity in class, but instead of writing a Boolean algebra formula, it is done in Python.  You will need to create 3 variables, `peanut_butter`, `jelly`, and `anchovies`, and assign different values (True or False) to test your conditional.
#
# | peanut_butter | jelly | anchovies | output |
# |---|---|---|:------:|
# | True | True | True |    False   |
# | True | True | False |    True   |
# | True | False | True |    False   |
# | True | False | False |    True   |
# | False | True | True |    False   |
# | False | True | False |    True   |
# | False | False | True |    False   |
# | False | False | False |    False   |
#
# **Each fact (variable) can only be used once in your if/else!**

# %%
peanut_butter = True
jelly = False
anchovies = False

if (peanut_butter or jelly) and not anchovies:
    result= True
    print(f"{result}")
else:
    result= False
    print(f"{result}")
# Out:
# True
