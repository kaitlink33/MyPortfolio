# %% [markdown]
# # CIS 115 Lab 1 - Introduction
# Complete all of the prompts below. Some require writting Python code, while others require fixing existing code. Once you have completed all parts. Save your lab and rename it as *lastName_firstName_lab1*.ipynb. Then submit your lab to canvas and raise your hand to request a TA/professor to check off your lab. If any corrections are needed, you can resubmit your lab as many times as needed during the class period. Be sure to make sure you are checked off **before** you leave class.
#
# ## Section 1: Basic Strings

# %% [markdown]
# Share your favorite animal by creating a string like `Hello, my favorite animal is Elephant`.
# **Do not use the `print` statement.**

# %%
"Hello, my favorite animal is Barn Owl."
# Out:
# 'Hello, my favorite animal is Barn Owl.'

# %% [markdown]
# Take the previous string you created and store it into a well-named variable. Then, output it using the _print_ statement.

# %%
animal_intro="Hello, my favorite animal is Barn Owl."
print(animal_intro)
# Out:
# Hello, my favorite animal is Barn Owl.

# %% [markdown]
# Add a second sentence to string you used above and output it here.  The second sentence should appear on a new line and tabbed.

# %%
print(animal_intro + "\n \n It is a stealthy, pretty creature that is reserved.")
# Out:
# Hello, my favorite animal is Barn Owl.
#
#  It is a stealthy, pretty creature that is reserved.

# %% [markdown]
# Add a third sentence to the string and output it here.  The third sentence should be tabbed in two spaces and appear on a new line.  The second sentence should be tabbed in one space and also appear on a new line.

# %%
print(animal_intro + "\n\tIt is a stealthy, pretty creature that is reserved.\n\t\t It also sees a lot.")
# Out:
# Hello, my favorite animal is Barn Owl.
# 	It is a stealthy, pretty creature that is reserved.
# 		 It also sees a lot.

# %% [markdown]
# ## Section 2: Quote or Quotes?

# %% [markdown]
# Fix the code snippets below so they output correctly

# %%
print('CIS 116 is pretty fun. Don\'t you agree?')
# Out:
# CIS 116 is pretty fun. Don't you agree?

# %%
print('Can you believe that \\t adds a tab character in a string in Python?')
# Out:
# Can you believe that \t adds a tab character in a string in Python?

# %%
print("I said, \"Hello there!\" to him.")
# Out:
# I said, "Hello there!" to him.

# %% [markdown]
# ## Section 3: Some numbers

# %% [markdown]
# Create a variable `num_items` and assign it the integer value `10`. Then, create another variable `price` and assign it the float value `2.50`. Create a variable `total_cost` by multiplying the values of `num_items` and `price` and print the results

# %%
num_items=10
price=2.50
total_cost=num_items*price
print(total_cost)
# Out:
# 25.0

# %% [markdown]
# Take the calculation above (`total_cost`) and find the remainder of dividing it by 7. This result should be stored into a variable and outputed.

# %%
total_cost_remainder=total_cost%7
print(total_cost_remainder)
# Out:
# 4.0

# %% [markdown]
# What is the cosine of 40? This result should be stored into a variable and outputed. (you can use math lib)

# %%
import math
cos_of_40=math.cos(40)
print(cos_of_40)
# Out:
# -0.6669380616522619

# %% [markdown]
# How can we calculate the average of five different variables? Show an example.

# %%
a=1
b=2
c=3
d=4
e=5
avg_of_5_vars=(a + b + c + d + e)/5

# %% [markdown]
# ## Section 4: Swapping

# %% [markdown]
# Swap the values of blue = 'red' and red = 'blue'. Do not modify or remove the lines marked as freeze. You may use as many temporary variables as needed.

# %%
blue = 'red'
red = 'blue'
### # (freeze) Don't change or remove the lines above.
swapper=blue
blue=red
red=swapper

## # (freeze) Don't change or remove the lines below.
print(red)
print(blue)
# Out:
# red
# blue
