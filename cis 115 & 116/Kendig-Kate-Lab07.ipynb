# %% [markdown]
# # Lab 7a - For loops and Lists
# ## Problem 1 - Favorite Five
# Create a sinlge list that contains 5 of your favorite things.  Store this list in a variable.

# %%
favorites=["owls", "books", "running", "mindfulness", "sleep"]

# %% [markdown]
# ## Problem 2 - Printing Lists
# Write a __for__ loop to print all of the items from your list, one per line.

# %%
index=0
for i in favorites:
        print(favorites[index])
        index+=1
# Out:
# owls
# books
# running
# mindfulness
# sleep

# %% [markdown]
# ## Problem 3 - Indexed Values
# Write a __for__ loop to print all of the items from your list along with their index.  The format of this should look something like `index: item`.

# %%
index=0
for i in favorites:
    print(f"{index}: {favorites[index]}")
    index+=1
# Out:
# 0: owls
# 1: books
# 2: running
# 3: mindfulness
# 4: sleep

# %% [markdown]
# ## Problem 4 - Expansion
# Add two of your favorite numbers to your list you created in _problem 1_. Your code must use the append function. After, use the __print__ function to output your list.

# %%
favorites.append(17)
favorites.append(414)
print(f"{favorites}")
# Out:
# ['owls', 'books', 'running', 'mindfulness', 'sleep', 17, 414]

# %% [markdown]
# ## Problem 5 - Deletion
# Remove the item in the middle of your list. After, use the __print__ function to output your list.

# %%
favorites.pop(3)
print(f"{favorites}")
# Out:
# ['owls', 'books', 'running', 'sleep', 17, 414]

# %% [markdown]
# ## Problem 6 - Another Odd List
# Create a new list that contains all of the odd numbers between 1 and 20, each divided by 2.  You may not hard-code the values and must use a __for loop__. After, use the __print__ function to output your list.

# %%
odd=[]
for i in range(1,21):
    if (i%2) != 0:
        odd.append((i/2))
print(odd)
# Out:
# [0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]

# %% [markdown]
# ## Problem 7 - List Comprehension
# Create a new list that contains all of the odd numbers between 1 and 20, each divided by 2.  You may not hard-code the values and must use __list comprehension__. After, use the __print__ function to output your list.

# %%
new=[]
for i in range(1,21):
    if (i%2) != 0:
        new.append((i/2))
print(new)

# %% [markdown]
# ## Problem 8 - Yet Another Triangle
# Create a code snippet that takes in a single input from the user as an integer.  Using this integer, use nested __for loops__ to create some ascii art.  The ascii art should look something like this:
#
# X
# X X
# X X X
# X X
# X
#
# The maximum number of `X`s printed out at the longest point (i.e. the center) corresponds to the number that is inputed by the user.  In the above example, the user entered 3 for the input.  You may use any character in place of `X`.

# %%
integer= int(input("Enter an integer:"))
for i in range(0,integer):
    for i in range(0,i):
          print("X", end="")
    print("")
for i in range(0,integer):
    n=integer-i
    for i in range(0,n):
         print("X",end="")
    print("")
# Out:
# X
# XX
# XXX
# XXXX
# XXXXX
# XXXXXX
# XXXXXXX
# XXXXXX
# XXXXX
# XXXX
# XXX
# XX
# X
